# %%
import time
from sqlalchemy import create_engine
import pandas as pd
import logging
import sys
# %load_ext memory_profiler

def main():
    logging.basicConfig(format='%(asctime)s %(levelname)s: %(message)s')
    log = logging.getLogger()
    log.setLevel(logging.INFO)

    log.info("Gerando dados")
    dados = [gerar_dado(i) for i in range(1_000, 300_000, 1_100)]
    log.info("Enviando dados")
    enviar_dados(dados)

def gerar_dado(n):
    start = time.time()
    acumul = 0
    for i in range(1, n+1):
        acumul += 1
    end = time.time()
    mem = %memit -o
    return { 'iterador': i, 'acumul': acumul, 'time_spent': ((end - start)*1000), 'memory_usage': str(mem).split()[2] }

def enviar_dados(dados):
    connection_str = "mysql+mysqlconnector://{user}:{password}@{host}/{db}"
    config = {
        "user": "admin",
        "password": "admin",
        "host": "localhost",
        "db":"projeto_pi"
    }
    con = create_engine(connection_str.format(**config))
    df = pd.DataFrame(dados)
#     df.to_sql("acumul_acelerate", con=con, if_exists="append", index=False)
    df.to_csv('./dados_algoritmo.csv')

main()
# Out:
# 2022-02-28 15:28:42,105 INFO: Gerando dados
# The memory_profiler extension is already loaded. To reload it, use:
#   %reload_ext memory_profiler
# peak memory: 211.15 MiB, increment: 0.00 MiB
# peak memory: 211.15 MiB, increment: 0.00 MiB
# peak memory: 211.15 MiB, increment: 0.00 MiB
# peak memory: 211.15 MiB, increment: 0.00 MiB
# peak memory: 211.15 MiB, increment: 0.00 MiB
# peak memory: 211.15 MiB, increment: 0.00 MiB
# peak memory: 211.13 MiB, increment: 0.00 MiB
# peak memory: 211.13 MiB, increment: 0.00 MiB
# peak memory: 211.13 MiB, increment: 0.00 MiB
# peak memory: 211.13 MiB, increment: 0.00 MiB
# peak memory: 211.15 MiB, increment: 0.02 MiB
# peak memory: 211.15 MiB, increment: 0.00 MiB
# peak memory: 211.15 MiB, increment: 0.00 MiB
# peak memory: 211.15 MiB, increment: 0.00 MiB
# peak memory: 211.15 MiB, increment: 0.00 MiB
# peak memory: 211.15 MiB, increment: 0.00 MiB
# peak memory: 211.15 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.12 MiB, increment: -0.02 MiB
# peak memory: 211.12 MiB, increment: 0.00 MiB
# peak memory: 211.12 MiB, increment: 0.00 MiB
# peak memory: 211.12 MiB, increment: 0.00 MiB
# peak memory: 211.12 MiB, increment: 0.00 MiB
# peak memory: 211.12 MiB, increment: 0.00 MiB
# peak memory: 211.12 MiB, increment: 0.00 MiB
# peak memory: 211.12 MiB, increment: 0.00 MiB
# peak memory: 211.12 MiB, increment: 0.00 MiB
# peak memory: 211.12 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.02 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.12 MiB, increment: -0.02 MiB
# peak memory: 211.12 MiB, increment: 0.00 MiB
# peak memory: 211.12 MiB, increment: 0.00 MiB
# peak memory: 211.12 MiB, increment: 0.00 MiB
# peak memory: 211.12 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.02 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.12 MiB, increment: -0.02 MiB
# peak memory: 211.14 MiB, increment: 0.02 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.12 MiB, increment: 0.00 MiB
# peak memory: 211.12 MiB, increment: 0.00 MiB
# peak memory: 211.12 MiB, increment: 0.00 MiB
# peak memory: 211.12 MiB, increment: 0.00 MiB
# peak memory: 211.12 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.02 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 211.14 MiB, increment: 0.00 MiB
# peak memory: 209.65 MiB, increment: -1.49 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.66 MiB, increment: -0.02 MiB
# peak memory: 209.68 MiB, increment: 0.02 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# peak memory: 209.68 MiB, increment: 0.00 MiB
# 2022-02-28 15:41:44,201 INFO: Enviando dados
# peak memory: 209.68 MiB, increment: 0.00 MiB
