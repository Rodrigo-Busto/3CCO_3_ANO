# %%
import time
from sqlalchemy import create_engine
import pandas as pd
import logging

# %load_ext memory_profiler

def main():
    logging.basicConfig(format='%(asctime)s %(levelname)s: %(message)s')
    log = logging.getLogger()
    log.setLevel(logging.INFO)

    log.info("Gerando dados")
    dados = [gerar_dado(i) for i in range(1_000, 300_000, 1_100)]
    log.info("Enviando dados")
    enviar_dados(dados)

def gerar_dado(n):
    start = time.time()
    acumul = 0
    for i in range(1, n+1):
        acumul += i
    end = time.time()
    mem = %memit -o
    return { 'iterador': i, 'acumul': acumul, 'time_spent': ((end - start)*1000), 'memory_usage': str(mem).split()[2] }

def enviar_dados(dados):
    connection_str = "mysql+mysqlconnector://{user}:{password}@{host}/{db}"
    config = {
        "user": "admin",
        "password": "admin",
        "host": "localhost",
        "db":"projeto_pi"
    }
    con = create_engine(connection_str.format(**config))
    df = pd.DataFrame(dados)
#     df.to_sql("acumul_acelerate", con=con, if_exists="append", index=False)
    df.to_csv('./dados_algoritmo.csv')

main()
# Out:
# 2022-02-28 16:55:51,553 INFO: Gerando dados
# peak memory: 106.18 MiB, increment: 0.80 MiB
# peak memory: 106.19 MiB, increment: 0.01 MiB
# peak memory: 106.17 MiB, increment: -0.02 MiB
# peak memory: 106.18 MiB, increment: 0.00 MiB
# peak memory: 106.18 MiB, increment: 0.00 MiB
# peak memory: 106.18 MiB, increment: 0.00 MiB
# peak memory: 106.19 MiB, increment: 0.01 MiB
# peak memory: 106.19 MiB, increment: 0.00 MiB
# peak memory: 106.19 MiB, increment: 0.00 MiB
# peak memory: 106.20 MiB, increment: 0.00 MiB
# peak memory: 106.20 MiB, increment: 0.00 MiB
# peak memory: 106.20 MiB, increment: 0.00 MiB
# peak memory: 106.12 MiB, increment: -0.07 MiB
# peak memory: 106.14 MiB, increment: 0.01 MiB
# peak memory: 106.14 MiB, increment: 0.00 MiB
# peak memory: 106.14 MiB, increment: 0.01 MiB
# peak memory: 106.14 MiB, increment: 0.00 MiB
# peak memory: 106.14 MiB, increment: 0.00 MiB
# peak memory: 106.14 MiB, increment: 0.00 MiB
# peak memory: 106.14 MiB, increment: 0.00 MiB
# peak memory: 106.14 MiB, increment: 0.00 MiB
# peak memory: 106.14 MiB, increment: 0.00 MiB
# peak memory: 106.15 MiB, increment: 0.00 MiB
# peak memory: 106.13 MiB, increment: -0.02 MiB
# peak memory: 106.13 MiB, increment: 0.00 MiB
# peak memory: 106.13 MiB, increment: 0.00 MiB
# peak memory: 106.14 MiB, increment: 0.01 MiB
# peak memory: 106.14 MiB, increment: 0.00 MiB
# peak memory: 106.14 MiB, increment: 0.00 MiB
# peak memory: 106.14 MiB, increment: 0.00 MiB
# peak memory: 106.14 MiB, increment: 0.00 MiB
# peak memory: 106.14 MiB, increment: -0.00 MiB
# peak memory: 106.14 MiB, increment: 0.00 MiB
# peak memory: 106.14 MiB, increment: 0.00 MiB
# peak memory: 106.14 MiB, increment: 0.00 MiB
# peak memory: 106.15 MiB, increment: 0.00 MiB
# peak memory: 106.15 MiB, increment: 0.00 MiB
# peak memory: 106.15 MiB, increment: 0.00 MiB
# peak memory: 106.16 MiB, increment: 0.00 MiB
# peak memory: 106.14 MiB, increment: -0.02 MiB
# peak memory: 106.14 MiB, increment: 0.00 MiB
# peak memory: 106.14 MiB, increment: 0.00 MiB
# peak memory: 106.14 MiB, increment: 0.00 MiB
# peak memory: 106.14 MiB, increment: 0.00 MiB
# peak memory: 106.16 MiB, increment: 0.02 MiB
# peak memory: 106.16 MiB, increment: 0.00 MiB
# peak memory: 106.17 MiB, increment: 0.01 MiB
# peak memory: 106.17 MiB, increment: 0.00 MiB
# peak memory: 106.17 MiB, increment: 0.00 MiB
# peak memory: 106.17 MiB, increment: 0.00 MiB
# peak memory: 106.17 MiB, increment: 0.00 MiB
# peak memory: 106.18 MiB, increment: 0.00 MiB
# peak memory: 106.18 MiB, increment: 0.00 MiB
# peak memory: 106.18 MiB, increment: 0.00 MiB
# peak memory: 106.18 MiB, increment: 0.00 MiB
# peak memory: 106.17 MiB, increment: -0.01 MiB
# peak memory: 106.17 MiB, increment: 0.00 MiB
# peak memory: 106.17 MiB, increment: 0.00 MiB
# peak memory: 106.17 MiB, increment: 0.00 MiB
# peak memory: 106.18 MiB, increment: 0.00 MiB
# peak memory: 106.18 MiB, increment: 0.00 MiB
# peak memory: 106.18 MiB, increment: 0.00 MiB
# peak memory: 106.18 MiB, increment: 0.00 MiB
# peak memory: 106.18 MiB, increment: 0.00 MiB
# peak memory: 106.18 MiB, increment: 0.00 MiB
# peak memory: 106.18 MiB, increment: 0.00 MiB
# peak memory: 106.18 MiB, increment: 0.00 MiB
# peak memory: 106.18 MiB, increment: 0.00 MiB
# peak memory: 106.18 MiB, increment: 0.00 MiB
# peak memory: 106.18 MiB, increment: 0.00 MiB
# peak memory: 106.18 MiB, increment: 0.00 MiB
# peak memory: 106.18 MiB, increment: 0.00 MiB
# peak memory: 106.19 MiB, increment: 0.00 MiB
# peak memory: 106.19 MiB, increment: 0.00 MiB
# peak memory: 106.19 MiB, increment: 0.00 MiB
# peak memory: 106.19 MiB, increment: 0.00 MiB
# peak memory: 106.19 MiB, increment: 0.00 MiB
# peak memory: 106.19 MiB, increment: 0.00 MiB
# peak memory: 106.19 MiB, increment: 0.00 MiB
# peak memory: 106.20 MiB, increment: 0.00 MiB
# peak memory: 106.20 MiB, increment: 0.00 MiB
# peak memory: 106.20 MiB, increment: 0.00 MiB
# peak memory: 106.20 MiB, increment: 0.00 MiB
# peak memory: 106.20 MiB, increment: 0.00 MiB
# peak memory: 106.20 MiB, increment: 0.00 MiB
# peak memory: 106.20 MiB, increment: 0.00 MiB
# peak memory: 106.21 MiB, increment: 0.00 MiB
# peak memory: 106.21 MiB, increment: 0.02 MiB
# peak memory: 106.22 MiB, increment: 0.01 MiB
# peak memory: 106.23 MiB, increment: 0.00 MiB
# peak memory: 106.23 MiB, increment: 0.00 MiB
# peak memory: 106.23 MiB, increment: 0.00 MiB
# peak memory: 106.23 MiB, increment: 0.00 MiB
# peak memory: 106.23 MiB, increment: 0.00 MiB
# peak memory: 106.23 MiB, increment: 0.00 MiB
# peak memory: 106.23 MiB, increment: 0.00 MiB
# peak memory: 106.23 MiB, increment: 0.00 MiB
# peak memory: 106.23 MiB, increment: 0.00 MiB
# peak memory: 106.30 MiB, increment: 0.07 MiB
# peak memory: 106.30 MiB, increment: 0.00 MiB
# peak memory: 106.30 MiB, increment: 0.00 MiB
# peak memory: 106.30 MiB, increment: 0.00 MiB
# peak memory: 106.30 MiB, increment: 0.00 MiB
# peak memory: 106.30 MiB, increment: 0.00 MiB
# peak memory: 106.30 MiB, increment: 0.00 MiB
# peak memory: 106.32 MiB, increment: 0.01 MiB
# peak memory: 106.32 MiB, increment: 0.01 MiB
# peak memory: 106.32 MiB, increment: 0.00 MiB
# peak memory: 106.34 MiB, increment: 0.01 MiB
# peak memory: 106.34 MiB, increment: 0.00 MiB
# peak memory: 106.34 MiB, increment: 0.00 MiB
# peak memory: 106.34 MiB, increment: 0.00 MiB
# peak memory: 106.34 MiB, increment: 0.00 MiB
# peak memory: 106.34 MiB, increment: 0.00 MiB
# peak memory: 106.34 MiB, increment: 0.00 MiB
# peak memory: 106.34 MiB, increment: 0.00 MiB
# peak memory: 106.34 MiB, increment: 0.00 MiB
# peak memory: 106.34 MiB, increment: 0.00 MiB
# peak memory: 106.34 MiB, increment: 0.00 MiB
# peak memory: 106.38 MiB, increment: 0.02 MiB
# peak memory: 106.38 MiB, increment: 0.00 MiB
# peak memory: 106.38 MiB, increment: 0.00 MiB
# peak memory: 106.39 MiB, increment: 0.00 MiB
# peak memory: 106.39 MiB, increment: 0.00 MiB
# peak memory: 106.38 MiB, increment: -0.01 MiB
# peak memory: 106.38 MiB, increment: 0.00 MiB
# peak memory: 106.38 MiB, increment: 0.00 MiB
# peak memory: 106.38 MiB, increment: 0.00 MiB
# peak memory: 106.38 MiB, increment: 0.00 MiB
# peak memory: 106.38 MiB, increment: 0.00 MiB
# peak memory: 106.38 MiB, increment: 0.00 MiB
# peak memory: 106.38 MiB, increment: 0.00 MiB
# peak memory: 106.38 MiB, increment: 0.00 MiB
# peak memory: 106.35 MiB, increment: -0.03 MiB
# peak memory: 106.35 MiB, increment: 0.00 MiB
# peak memory: 106.35 MiB, increment: 0.00 MiB
# peak memory: 106.36 MiB, increment: 0.00 MiB
# peak memory: 106.36 MiB, increment: 0.00 MiB
# peak memory: 106.36 MiB, increment: 0.00 MiB
# peak memory: 106.36 MiB, increment: 0.01 MiB
# peak memory: 106.38 MiB, increment: 0.01 MiB
# peak memory: 106.38 MiB, increment: 0.00 MiB
# peak memory: 106.38 MiB, increment: 0.00 MiB
# peak memory: 106.42 MiB, increment: 0.04 MiB
# peak memory: 106.43 MiB, increment: 0.01 MiB
# peak memory: 106.43 MiB, increment: 0.00 MiB
# peak memory: 106.45 MiB, increment: 0.02 MiB
# peak memory: 106.46 MiB, increment: 0.02 MiB
# peak memory: 106.48 MiB, increment: 0.02 MiB
# peak memory: 106.48 MiB, increment: 0.00 MiB
# peak memory: 106.49 MiB, increment: 0.00 MiB
# peak memory: 106.49 MiB, increment: 0.00 MiB
# peak memory: 106.49 MiB, increment: 0.00 MiB
# peak memory: 106.49 MiB, increment: 0.00 MiB
# peak memory: 106.49 MiB, increment: 0.00 MiB
# peak memory: 106.49 MiB, increment: 0.00 MiB
# peak memory: 106.49 MiB, increment: 0.00 MiB
# peak memory: 106.49 MiB, increment: 0.00 MiB
# peak memory: 106.48 MiB, increment: -0.02 MiB
# peak memory: 106.50 MiB, increment: 0.02 MiB
# peak memory: 106.50 MiB, increment: 0.00 MiB
# peak memory: 106.50 MiB, increment: 0.00 MiB
# peak memory: 106.49 MiB, increment: -0.00 MiB
# peak memory: 106.50 MiB, increment: 0.00 MiB
# peak memory: 106.50 MiB, increment: 0.00 MiB
# peak memory: 106.49 MiB, increment: -0.00 MiB
# peak memory: 106.49 MiB, increment: 0.00 MiB
# peak memory: 106.49 MiB, increment: 0.00 MiB
# peak memory: 106.49 MiB, increment: 0.00 MiB
# peak memory: 106.49 MiB, increment: 0.00 MiB
# peak memory: 106.50 MiB, increment: 0.00 MiB
# peak memory: 106.50 MiB, increment: 0.00 MiB
# peak memory: 106.50 MiB, increment: 0.00 MiB
# peak memory: 106.50 MiB, increment: 0.00 MiB
# peak memory: 106.50 MiB, increment: 0.00 MiB
# peak memory: 106.50 MiB, increment: 0.00 MiB
# peak memory: 106.50 MiB, increment: 0.00 MiB
# peak memory: 106.50 MiB, increment: 0.00 MiB
# peak memory: 106.51 MiB, increment: 0.00 MiB
# peak memory: 106.51 MiB, increment: 0.00 MiB
# peak memory: 106.49 MiB, increment: -0.02 MiB
# peak memory: 106.49 MiB, increment: 0.00 MiB
# peak memory: 106.51 MiB, increment: 0.02 MiB
# peak memory: 106.51 MiB, increment: 0.00 MiB
# peak memory: 106.51 MiB, increment: 0.00 MiB
# peak memory: 106.51 MiB, increment: 0.00 MiB
# peak memory: 106.51 MiB, increment: 0.00 MiB
# peak memory: 106.51 MiB, increment: 0.00 MiB
# peak memory: 106.51 MiB, increment: 0.00 MiB
# peak memory: 106.51 MiB, increment: 0.00 MiB
# peak memory: 106.51 MiB, increment: 0.00 MiB
# peak memory: 106.51 MiB, increment: 0.00 MiB
# peak memory: 106.51 MiB, increment: 0.00 MiB
# peak memory: 106.50 MiB, increment: -0.01 MiB
# peak memory: 106.52 MiB, increment: 0.02 MiB
# peak memory: 106.52 MiB, increment: 0.00 MiB
# peak memory: 106.52 MiB, increment: 0.00 MiB
# peak memory: 106.51 MiB, increment: -0.00 MiB
# peak memory: 106.52 MiB, increment: 0.00 MiB
# peak memory: 106.52 MiB, increment: 0.00 MiB
# peak memory: 106.52 MiB, increment: 0.00 MiB
# peak memory: 106.52 MiB, increment: 0.00 MiB
# peak memory: 106.52 MiB, increment: 0.00 MiB
# peak memory: 106.54 MiB, increment: 0.02 MiB
# peak memory: 106.54 MiB, increment: 0.00 MiB
# peak memory: 106.54 MiB, increment: 0.00 MiB
# peak memory: 106.54 MiB, increment: 0.00 MiB
# peak memory: 106.54 MiB, increment: 0.00 MiB
# peak memory: 106.55 MiB, increment: 0.01 MiB
# peak memory: 106.55 MiB, increment: -0.00 MiB
# peak memory: 106.55 MiB, increment: 0.00 MiB
# peak memory: 106.55 MiB, increment: 0.00 MiB
# peak memory: 106.55 MiB, increment: 0.00 MiB
# peak memory: 106.55 MiB, increment: 0.00 MiB
# peak memory: 106.53 MiB, increment: 0.03 MiB
# peak memory: 106.53 MiB, increment: 0.00 MiB
# peak memory: 106.54 MiB, increment: 0.00 MiB
# peak memory: 106.54 MiB, increment: 0.00 MiB
# peak memory: 106.54 MiB, increment: 0.02 MiB
# peak memory: 106.54 MiB, increment: 0.00 MiB
# peak memory: 106.54 MiB, increment: 0.00 MiB
# peak memory: 106.54 MiB, increment: 0.00 MiB
# peak memory: 106.54 MiB, increment: 0.00 MiB
# peak memory: 106.54 MiB, increment: 0.00 MiB
# peak memory: 106.54 MiB, increment: 0.00 MiB
# peak memory: 106.54 MiB, increment: -0.01 MiB
# peak memory: 106.54 MiB, increment: 0.01 MiB
# peak memory: 106.54 MiB, increment: 0.02 MiB
# peak memory: 106.51 MiB, increment: -0.03 MiB
# peak memory: 106.51 MiB, increment: 0.00 MiB
# peak memory: 106.51 MiB, increment: 0.00 MiB
# peak memory: 106.51 MiB, increment: 0.00 MiB
# peak memory: 106.51 MiB, increment: 0.00 MiB
# peak memory: 106.51 MiB, increment: 0.00 MiB
# peak memory: 106.50 MiB, increment: -0.01 MiB
# peak memory: 106.53 MiB, increment: 0.02 MiB
# peak memory: 106.53 MiB, increment: 0.00 MiB
# peak memory: 106.53 MiB, increment: 0.00 MiB
# peak memory: 106.53 MiB, increment: 0.00 MiB
# peak memory: 106.53 MiB, increment: 0.00 MiB
# peak memory: 106.53 MiB, increment: 0.00 MiB
# peak memory: 106.54 MiB, increment: 0.01 MiB
# peak memory: 106.54 MiB, increment: 0.00 MiB
# peak memory: 106.54 MiB, increment: 0.00 MiB
# peak memory: 106.54 MiB, increment: 0.00 MiB
# peak memory: 106.55 MiB, increment: 0.00 MiB
# peak memory: 106.55 MiB, increment: 0.00 MiB
# peak memory: 106.55 MiB, increment: 0.00 MiB
# peak memory: 106.55 MiB, increment: 0.00 MiB
# peak memory: 106.55 MiB, increment: 0.00 MiB
# peak memory: 106.55 MiB, increment: 0.00 MiB
# peak memory: 106.55 MiB, increment: 0.00 MiB
# peak memory: 106.55 MiB, increment: 0.00 MiB
# peak memory: 106.55 MiB, increment: 0.00 MiB
# peak memory: 106.55 MiB, increment: 0.01 MiB
# peak memory: 106.55 MiB, increment: 0.00 MiB
# peak memory: 106.55 MiB, increment: 0.00 MiB
# peak memory: 106.55 MiB, increment: 0.00 MiB
# peak memory: 106.55 MiB, increment: 0.00 MiB
# peak memory: 106.55 MiB, increment: 0.00 MiB
# peak memory: 106.55 MiB, increment: 0.00 MiB
# peak memory: 106.55 MiB, increment: -0.00 MiB
# peak memory: 106.55 MiB, increment: 0.00 MiB
# peak memory: 106.56 MiB, increment: 0.00 MiB
# peak memory: 106.56 MiB, increment: 0.00 MiB
# peak memory: 106.56 MiB, increment: 0.00 MiB
# peak memory: 106.56 MiB, increment: 0.00 MiB
# peak memory: 106.56 MiB, increment: 0.00 MiB
# peak memory: 106.56 MiB, increment: 0.00 MiB
# peak memory: 106.57 MiB, increment: 0.00 MiB
# peak memory: 106.60 MiB, increment: 0.03 MiB
# 2022-02-28 17:08:40,683 INFO: Enviando dados
# peak memory: 106.60 MiB, increment: 0.00 MiB
